-- %% [markdown]
-- # [PetAI_Core_DB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PetAI_Core_DB]    Script Date: 3/19/2026 1:42:57 PM ******/
CREATE DATABASE [PetAI_Core_DB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PetAI_Core_DB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\PetAI_Core_DB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PetAI_Core_DB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\PetAI_Core_DB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [PetAI_Core_DB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PetAI_Core_DB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PetAI_Core_DB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET ARITHABORT OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [PetAI_Core_DB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PetAI_Core_DB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PetAI_Core_DB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [PetAI_Core_DB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PetAI_Core_DB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [PetAI_Core_DB] SET  MULTI_USER 
GO
ALTER DATABASE [PetAI_Core_DB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PetAI_Core_DB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PetAI_Core_DB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PetAI_Core_DB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PetAI_Core_DB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PetAI_Core_DB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [PetAI_Core_DB] SET QUERY_STORE = ON
GO
ALTER DATABASE [PetAI_Core_DB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Customer]

-- %%
USE [PetAI_Core_DB]
GO

-- %%
/****** Object:  Table [dbo].[Customer]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customer](
	[CustomerID] [varchar](20) NOT NULL,
	[CustomerName] [nvarchar](100) NOT NULL,
	[Phone] [varchar](15) NULL,
	[Address] [nvarchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[CustomerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Disease]

-- %%
/****** Object:  Table [dbo].[Disease]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Disease](
	[DiseaseID] [varchar](20) NOT NULL,
	[DiseaseName] [nvarchar](100) NOT NULL,
	[MainSymptom] [nvarchar](max) NULL,
	[MedicalAdvice] [nvarchar](max) NULL,
	[DangerLevel] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[DiseaseID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
/****** Object:  Table [dbo].[Employee]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employee](
	[EmployeeID] [varchar](20) NOT NULL,
	[FullName] [nvarchar](100) NOT NULL,
	[Position] [nvarchar](50) NULL,
	[PhoneNumber] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[EmployeeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HealthRecord]

-- %%
/****** Object:  Table [dbo].[HealthRecord]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HealthRecord](
	[RecordID] [int] IDENTITY(1,1) NOT NULL,
	[PetID] [varchar](20) NULL,
	[Temperature] [float] NULL,
	[HeartRate] [int] NULL,
	[DiagnosisID] [varchar](20) NULL,
	[PredictionDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[RecordID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Invoice]

-- %%
/****** Object:  Table [dbo].[Invoice]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Invoice](
	[InvoiceID] [varchar](20) NOT NULL,
	[PetID] [varchar](20) NULL,
	[EmployeeID] [varchar](20) NULL,
	[TotalAmount] [decimal](18, 2) NULL,
	[PaymentDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[InvoiceID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InvoiceDetail]

-- %%
/****** Object:  Table [dbo].[InvoiceDetail]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InvoiceDetail](
	[DetailID] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceID] [varchar](20) NULL,
	[ServiceID] [varchar](20) NULL,
	[MedicineID] [varchar](20) NULL,
	[Quantity] [int] NULL,
	[SubTotal] [decimal](18, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[DetailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Medicine]

-- %%
/****** Object:  Table [dbo].[Medicine]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Medicine](
	[MedicineID] [varchar](20) NOT NULL,
	[MedicineName] [nvarchar](100) NOT NULL,
	[Unit] [nvarchar](20) NULL,
	[Price] [decimal](18, 2) NULL,
	[StockQuantity] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[MedicineID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pet]

-- %%
/****** Object:  Table [dbo].[Pet]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pet](
	[PetID] [varchar](20) NOT NULL,
	[PetName] [nvarchar](100) NOT NULL,
	[Species] [nvarchar](50) NULL,
	[Breed] [nvarchar](50) NULL,
	[CustomerID] [varchar](20) NULL,
	[CreatedAt] [datetime] NULL,
	[Weight] [float] NULL,
	[Age] [int] NULL,
	[Note] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[PetID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Service]

-- %%
/****** Object:  Table [dbo].[Service]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Service](
	[ServiceID] [varchar](20) NOT NULL,
	[ServiceName] [nvarchar](100) NOT NULL,
	[Price] [decimal](18, 2) NULL,
	[Note] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[ServiceID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StayRegistration]

-- %%
/****** Object:  Table [dbo].[StayRegistration]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StayRegistration](
	[StayID] [varchar](20) NOT NULL,
	[PetID] [varchar](20) NULL,
	[EmployeeID] [varchar](20) NULL,
	[CheckInDate] [datetime] NULL,
	[ExpectedCheckOutDate] [datetime] NULL,
	[ActualCheckOutDate] [datetime] NULL,
	[StayReason] [nvarchar](max) NULL,
	[DailyStatus] [nvarchar](max) NULL,
	[UnitPrice] [decimal](18, 2) NULL,
	[TotalStayAmount]  AS (datediff(day,[CheckInDate],isnull([ActualCheckOutDate],getdate()))*[UnitPrice]),
	[Status] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[StayID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 3/19/2026 1:42:57 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserID] [varchar](50) NOT NULL,
	[Username] [nvarchar](50) NOT NULL,
	[Password] [nvarchar](50) NOT NULL,
	[Role] [nvarchar](20) NULL,
	[Email] [nvarchar](100) NULL,
	[EmployeeID] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customer]

-- %%
INSERT [dbo].[Customer] ([CustomerID], [CustomerName], [Phone], [Address]) VALUES (N'KH001', N'Trần Minh Tâm', N'0911223344', N'Ninh Kiều, Cần Thơ')
INSERT [dbo].[Customer] ([CustomerID], [CustomerName], [Phone], [Address]) VALUES (N'KH002', N'Lê Thị Hoa', N'0944556677', N'An Giang')
INSERT [dbo].[Customer] ([CustomerID], [CustomerName], [Phone], [Address]) VALUES (N'KH004', N'HJK', N'0987666666', N'HDH')
INSERT [dbo].[Customer] ([CustomerID], [CustomerName], [Phone], [Address]) VALUES (N'KH005', N'ÁDFG', N'0987876565', N'JBHV')
INSERT [dbo].[Customer] ([CustomerID], [CustomerName], [Phone], [Address]) VALUES (N'KH006', N'ád', N'0867656677', N'àgggh')
GO

-- %% [markdown]
-- # [dbo].[Disease]

-- %%
INSERT [dbo].[Disease] ([DiseaseID], [DiseaseName], [MainSymptom], [MedicalAdvice], [DangerLevel]) VALUES (N'D001', N'Sốt siêu vi', N'Mệt mỏi, Biếng ăn, Nhiệt độ cao > 39 độ', N'Cho bé uống nhiều nước và nghỉ ngơi.', N'Trung bình')
INSERT [dbo].[Disease] ([DiseaseID], [DiseaseName], [MainSymptom], [MedicalAdvice], [DangerLevel]) VALUES (N'D002', N'Sốc nhiệt', N'Nhiệt độ cơ thể > 40 độ, thở gấp, chảy dãi', N'Làm mát cơ thể bằng khăn ẩm và đưa đi cấp cứu ngay.', N'Rất cao')
INSERT [dbo].[Disease] ([DiseaseID], [DiseaseName], [MainSymptom], [MedicalAdvice], [DangerLevel]) VALUES (N'D003', N'Viêm da (Nấm)', N'Ngứa ngáy, rụng lông theo mảng, da đỏ', N'Vệ sinh da bằng xà phòng chuyên dụng.', N'Thấp')
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
INSERT [dbo].[Employee] ([EmployeeID], [FullName], [Position], [PhoneNumber]) VALUES (N'NV001', N'Nguyễn Anh Thư', N'Quản lý hệ thống', N'0901234567')
INSERT [dbo].[Employee] ([EmployeeID], [FullName], [Position], [PhoneNumber]) VALUES (N'NV002', N'Lê Minh bác sĩ', N'Bác sĩ thú y', N'0907654321')
GO

-- %% [markdown]
-- # [dbo].[Medicine]

-- %%
INSERT [dbo].[Medicine] ([MedicineID], [MedicineName], [Unit], [Price], [StockQuantity]) VALUES (N'M001', N'Thuốc hạ sốt Pet', N'Viên', CAST(15000.00 AS Decimal(18, 2)), 100)
INSERT [dbo].[Medicine] ([MedicineID], [MedicineName], [Unit], [Price], [StockQuantity]) VALUES (N'M002', N'Kháng sinh viêm da', N'Gói', CAST(25000.00 AS Decimal(18, 2)), 50)
GO

-- %% [markdown]
-- # [dbo].[Pet]

-- %%
INSERT [dbo].[Pet] ([PetID], [PetName], [Species], [Breed], [CustomerID], [CreatedAt], [Weight], [Age], [Note]) VALUES (N'P001', N'Lu Lu', N'Chó', N'Poodle', N'KH001', CAST(N'2026-03-15T18:49:54.670' AS DateTime), 4.5, 2, N'KHỎE MẠNH')
INSERT [dbo].[Pet] ([PetID], [PetName], [Species], [Breed], [CustomerID], [CreatedAt], [Weight], [Age], [Note]) VALUES (N'P002', N'Mimi', N'Mèo', N'Anh lông ngắn', N'KH002', CAST(N'2026-03-15T18:49:54.670' AS DateTime), 5.2, 3, N'BỆNH RỒI KÌA')
GO

-- %% [markdown]
-- # [dbo].[Service]

-- %%
INSERT [dbo].[Service] ([ServiceID], [ServiceName], [Price], [Note]) VALUES (N'S001', N'TẮM GỘI ', CAST(150000.00 AS Decimal(18, 2)), N'')
INSERT [dbo].[Service] ([ServiceID], [ServiceName], [Price], [Note]) VALUES (N'S002', N'spa', CAST(1000000.00 AS Decimal(18, 2)), N'dơ')
GO

-- %% [markdown]
-- # [dbo].[StayRegistration]

-- %%
INSERT [dbo].[StayRegistration] ([StayID], [PetID], [EmployeeID], [CheckInDate], [ExpectedCheckOutDate], [ActualCheckOutDate], [StayReason], [DailyStatus], [UnitPrice], [Status]) VALUES (N'ST001', N'P001', N'NV002', CAST(N'2026-03-10T00:00:00.000' AS DateTime), CAST(N'2026-03-20T00:00:00.000' AS DateTime), NULL, N'Điều trị sốt siêu vi', N'Ngày 1: Ăn ít. Ngày 2: Đã ổn định hơn.', CAST(120000.00 AS Decimal(18, 2)), N'Đang lưu trú')
INSERT [dbo].[StayRegistration] ([StayID], [PetID], [EmployeeID], [CheckInDate], [ExpectedCheckOutDate], [ActualCheckOutDate], [StayReason], [DailyStatus], [UnitPrice], [Status]) VALUES (N'ST002', N'P002', N'NV001', CAST(N'2026-03-12T00:00:00.000' AS DateTime), CAST(N'2026-03-15T00:00:00.000' AS DateTime), NULL, N'Gửi chăm sóc khi chủ vắng nhà', N'Sức khỏe rất tốt.', CAST(100000.00 AS Decimal(18, 2)), N'Đang lưu trú')
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
INSERT [dbo].[Users] ([UserID], [Username], [Password], [Role], [Email], [EmployeeID]) VALUES (N'U001', N'admin', N'123', N'Admin', N'admin@petai.com', N'NV001')
INSERT [dbo].[Users] ([UserID], [Username], [Password], [Role], [Email], [EmployeeID]) VALUES (N'U002', N'doctor1', N'123', N'Doctor', N'doctor@petai.com', N'NV002')
GO

-- %% [markdown]
-- # [DF__HealthRec__Predi__45F365D3]

-- %%
ALTER TABLE [dbo].[HealthRecord] ADD  DEFAULT (getdate()) FOR [PredictionDate]
GO

-- %% [markdown]
-- # [DF__Invoice__Payment__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Invoice] ADD  DEFAULT (getdate()) FOR [PaymentDate]
GO

-- %% [markdown]
-- # [DF__Pet__CreatedAt__3F466844]

-- %%
ALTER TABLE [dbo].[Pet] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__StayRegis__Check__5812160E]

-- %%
ALTER TABLE [dbo].[StayRegistration] ADD  DEFAULT (getdate()) FOR [CheckInDate]
GO

-- %% [markdown]
-- # [DF__StayRegis__UnitP__59063A47]

-- %%
ALTER TABLE [dbo].[StayRegistration] ADD  DEFAULT ((0)) FOR [UnitPrice]
GO

-- %% [markdown]
-- # [FK__HealthRec__Diagn__44FF419A]

-- %%
ALTER TABLE [dbo].[HealthRecord]  WITH CHECK ADD FOREIGN KEY([DiagnosisID])
REFERENCES [dbo].[Disease] ([DiseaseID])
GO

-- %% [markdown]
-- # [FK__HealthRec__PetID__440B1D61]

-- %%
ALTER TABLE [dbo].[HealthRecord]  WITH CHECK ADD FOREIGN KEY([PetID])
REFERENCES [dbo].[Pet] ([PetID])
GO

-- %% [markdown]
-- # [FK__Invoice__Employe__4D94879B]

-- %%
ALTER TABLE [dbo].[Invoice]  WITH CHECK ADD FOREIGN KEY([EmployeeID])
REFERENCES [dbo].[Employee] ([EmployeeID])
GO

-- %% [markdown]
-- # [FK__Invoice__PetID__4CA06362]

-- %%
ALTER TABLE [dbo].[Invoice]  WITH CHECK ADD FOREIGN KEY([PetID])
REFERENCES [dbo].[Pet] ([PetID])
GO

-- %% [markdown]
-- # [FK__InvoiceDe__Invoi__5165187F]

-- %%
ALTER TABLE [dbo].[InvoiceDetail]  WITH CHECK ADD FOREIGN KEY([InvoiceID])
REFERENCES [dbo].[Invoice] ([InvoiceID])
GO

-- %% [markdown]
-- # [FK__InvoiceDe__Medic__534D60F1]

-- %%
ALTER TABLE [dbo].[InvoiceDetail]  WITH CHECK ADD FOREIGN KEY([MedicineID])
REFERENCES [dbo].[Medicine] ([MedicineID])
GO

-- %% [markdown]
-- # [FK__InvoiceDe__Servi__52593CB8]

-- %%
ALTER TABLE [dbo].[InvoiceDetail]  WITH CHECK ADD FOREIGN KEY([ServiceID])
REFERENCES [dbo].[Service] ([ServiceID])
GO

-- %% [markdown]
-- # [FK__Pet__CustomerID__3E52440B]

-- %%
ALTER TABLE [dbo].[Pet]  WITH CHECK ADD FOREIGN KEY([CustomerID])
REFERENCES [dbo].[Customer] ([CustomerID])
GO

-- %% [markdown]
-- # [FK__StayRegis__Emplo__571DF1D5]

-- %%
ALTER TABLE [dbo].[StayRegistration]  WITH CHECK ADD FOREIGN KEY([EmployeeID])
REFERENCES [dbo].[Employee] ([EmployeeID])
GO

-- %% [markdown]
-- # [FK__StayRegis__PetID__5629CD9C]

-- %%
ALTER TABLE [dbo].[StayRegistration]  WITH CHECK ADD FOREIGN KEY([PetID])
REFERENCES [dbo].[Pet] ([PetID])
GO

-- %% [markdown]
-- # [FK__Users__EmployeeI__398D8EEE]

-- %%
ALTER TABLE [dbo].[Users]  WITH CHECK ADD FOREIGN KEY([EmployeeID])
REFERENCES [dbo].[Employee] ([EmployeeID])
GO

-- %% [markdown]
-- # [PetAI_Core_DB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PetAI_Core_DB] SET  READ_WRITE 
GO
